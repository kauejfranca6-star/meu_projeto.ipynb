# %% [markdown]
# <a href="https://colab.research.google.com/github/kauejfranca6-star/meu_projeto.ipynb/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alunos = []

while True:
    print("\n1 - Cadastrar aluno")
    print("2 - Listar alunos")
    print("0 - Sair")

    opcao = input("Escolha: ")

    if opcao == "1":
        nome = input("Digite o nome: ")

        if nome == "":
            print("Nome não pode ser vazio.")
        else:
            alunos.append(nome)
            print("Aluno cadastrado com sucesso!")

    elif opcao == "2":
        print("\nLista de alunos:")

        if len(alunos) == 0:
            print("Nenhum aluno cadastrado.")
        else:
            for aluno in alunos:
                print(aluno)

            print(f"\nQuantidade de alunos: {len(alunos)}")

    elif opcao == "0":
        print("Programa encerrado.")
        break

    else:
        print("Opção inválida.")
# Out:
# 1 - Cadastrar aluno
# 2 - Listar alunos
# 0 - Sair
# Escolha: 2
#
# Lista de alunos:
# Nenhum aluno cadastrado.
#
# 1 - Cadastrar aluno
# 2 - Listar alunos
# 0 - Sair
# Escolha: pedro
# Opção inválida.
#
# 1 - Cadastrar aluno
# 2 - Listar alunos
# 0 - Sair
# Escolha: 1
# Digite o nome: pedro
# Aluno cadastrado com sucesso!
#
# 1 - Cadastrar aluno
# 2 - Listar alunos
# 0 - Sair
# Escolha: 2
#
# Lista de alunos:
# pedro
#
# Quantidade de alunos: 1
#
# 1 - Cadastrar aluno
# 2 - Listar alunos
# 0 - Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_983/1334966024.py in <cell line: 0>()
#       6     print("0 - Sair")
#       7
# ----> 8     opcao = input("Escolha: ")
#       9
#      10     if opcao == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
